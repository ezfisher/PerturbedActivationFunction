# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv
import os
import glob
from typing import Optional

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data as data
import torch.optim as optim
import torchvision
import torchvision.transforms as T

# %%
dataset_path = '/home/hari/data/Personal/flower_photos'
classes = glob.glob(os.path.join(dataset_path, '**'))
images = glob.glob(os.path.join(dataset_path, '**/*.jpg'))
print(len(classes))
print(len(images))
# Out:
# 5
# 3670

# %%
for c in classes:
    images = glob.glob(os.path.join(dataset_path, c, '*.jpg'))
    print(len(images))
# Out:
# 641
# 699
# 633
# 799
# 898

# %%
transforms = T.Compose([
    T.ToTensor(),
    T.Resize((256, 256), antialias=False),
])

# %%
class Dataset(data.Dataset):
    def __init__(self, root_directory, transforms=None, train=True):
        self.root_directory = root_directory
        self.transforms = transforms
        self.train_size = 0.8
        self.train = train
        self.images = self.__train_validation_split__()
        classes = [c.split('/')[-1] for c in sorted(glob.glob(os.path.join(root_directory, '**')))]
        self.class_dict = {c : i for i, c in enumerate(classes)}

    def __train_validation_split__(self):
        images = glob.glob(os.path.join(self.root_directory, '**/*.jpg'))
        _size = int(len(images) * self.train_size) if self.train else int(len(images) * (1 - self.train_size))
        indices = np.random.choice(len(images), _size, replace=False)
        images = np.array(images)[indices]
        return images

    def __class_tonumeric__(self, label):
        return self.class_dict[label]
    
    def __getitem__(self, index):
        path = self.images[index]
        label = path.split('/')[-2]
        label = self.__class_tonumeric__(label)
        image = cv.imread(path)
        image = cv.cvtColor(image, cv.COLOR_BGR2RGB)
        if self.transforms is not None:
            image = self.transforms(image)
        return image, label
    
    def __len__(self):
        return len(self.images)

# %%
dataset = Dataset(root_directory=dataset_path, transforms=transforms, train=True)
validset = Dataset(root_directory=dataset_path, transforms=transforms, train=False)
dataloader = data.DataLoader(dataset, batch_size=4, shuffle=True, drop_last=True)
validloader = data.DataLoader(validset, batch_size=1, shuffle=True, drop_last=True)
X, y = next(iter(dataloader))
print(X.shape, y.shape)
# Out:
# torch.Size([4, 3, 256, 256]) torch.Size([4])

# %%
class LearnedReLU(nn.Module):
    def __init__(self, learning_epochs):
        super().__init__()
        self.learning_epochs = learning_epochs
        positive_coefficient = torch.normal(torch.ones(1), torch.ones(1))
        negative_coefficient = torch.normal(torch.zeros(1), torch.ones(1))
        self.positive_coefficient = nn.Parameter(positive_coefficient)
        self.negative_coefficient = nn.Parameter(negative_coefficient)

    def forward(self, X, epoch=None):
        _p_copy = self.positive_coefficient.data.clone()
        _n_copy = self.negative_coefficient.data.clone()
        if epoch is None or epoch >= self.learning_epochs:
            _p_copy, _n_copy = nn.Parameter(torch.ones(1)), nn.Parameter(torch.zeros(1))
        out = torch.where(X>=0, _p_copy * X, _n_copy * X)
        return out

# %%
class PerturbedReLU(nn.Module):
    def __init__(self, epsilon=0.01):
        super().__init__()
        self.epsilon = epsilon
    
    def forward(self, X):
        activated = F.relu(X)
        perturbation = torch.normal(torch.ones(X.shape)*self.epsilon, torch.ones(X.shape)*self.epsilon)
        return activated + perturbation

# %%
class ControlNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=(11, 11), stride=(5, 5))
        self.conv2 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=(9, 9), stride=(3, 3))
        self.conv3 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=(7, 7), stride=(1, 1))
        self.conv4 = nn.Conv2d(in_channels=128, out_channels=64, kernel_size=(5, 5), stride=(1, 1))
        self.linear1 = nn.Linear(1024, 512)
        self.linear2 = nn.Linear(512, 5)
        self.flatten = nn.Flatten()
        self.act = nn.ReLU()
        self.softmax = nn.Softmax(dim=1)

    def forward(self, X):
        out = self.conv1(X)
        out = self.act(out)
        out = self.conv2(out)
        out = self.act(out)
        out = self.conv3(out)
        out = self.act(out)
        out = self.conv4(out)
        out = self.act(out)
        out = self.flatten(out)
        out = self.linear1(out)
        out = self.act(out)
        out = self.linear2(out)
        out = self.softmax(out)
        return out

# %%
# class TestNetwork(nn.Module):
#     def __init__(self, activation_learning_epochs):
#         super().__init__()
#         self.activation_learning_epochs = activation_learning_epochs
#         self.conv1 = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=(11, 11), stride=(5, 5))
#         self.act1 = LearnedReLU(activation_learning_epochs)
#         self.conv2 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=(9, 9), stride=(3, 3))
#         self.act2 = LearnedReLU(activation_learning_epochs)
#         self.conv3 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=(7, 7), stride=(1, 1))
#         self.act3 = LearnedReLU(activation_learning_epochs)
#         self.conv4 = nn.Conv2d(in_channels=128, out_channels=64, kernel_size=(5, 5), stride=(1, 1))
#         self.act4 = LearnedReLU(activation_learning_epochs)
#         self.linear1 = nn.Linear(1024, 512)
#         self.act5 = LearnedReLU(activation_learning_epochs)
#         self.linear2 = nn.Linear(512, 5)
#         self.flatten = nn.Flatten()
#         self.softmax = nn.Softmax(dim=1)

#     def forward(self, X, epoch):
#         out = self.act1(self.conv1(X), epoch)
#         out = self.act2(self.conv2(out), epoch)
#         out = self.act3(self.conv3(out), epoch)
#         out = self.act4(self.conv4(out), epoch)
#         out = self.flatten(out)
#         out = self.act5(self.linear1(out), epoch)
#         out = self.softmax(self.linear2(out))
#         return out

class TestNetwork1(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=(11, 11), stride=(5, 5))
        self.act1 = PerturbedReLU(epsilon=0.01)
        self.conv2 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=(9, 9), stride=(3, 3))
        self.act2 = PerturbedReLU(epsilon=0.01)
        self.conv3 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=(7, 7), stride=(1, 1))
        self.act3 = PerturbedReLU(epsilon=0.01)
        self.conv4 = nn.Conv2d(in_channels=128, out_channels=64, kernel_size=(5, 5), stride=(1, 1))
        self.act4 = PerturbedReLU(epsilon=0.01)
        self.linear1 = nn.Linear(1024, 512)
        self.act5 = PerturbedReLU(epsilon=0.01)
        self.linear2 = nn.Linear(512, 5)
        self.flatten = nn.Flatten()
        self.softmax = nn.Softmax(dim=1)

    def forward(self, X):
        out = self.act1(self.conv1(X))
        out = self.act2(self.conv2(out))
        out = self.act3(self.conv3(out))
        out = self.act4(self.conv4(out))
        out = self.flatten(out)
        out = self.act5(self.linear1(out))
        out = self.softmax(self.linear2(out))
        return out

class TestNetwork2(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=(11, 11), stride=(5, 5))
        self.act1 = PerturbedReLU(epsilon=0.01)
        self.conv2 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=(9, 9), stride=(3, 3))
        self.act2 = PerturbedReLU(epsilon=0.005)
        self.conv3 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=(7, 7), stride=(1, 1))
        self.act3 = PerturbedReLU(epsilon=0.001)
        self.conv4 = nn.Conv2d(in_channels=128, out_channels=64, kernel_size=(5, 5), stride=(1, 1))
        self.act4 = PerturbedReLU(epsilon=0.0005)
        self.linear1 = nn.Linear(1024, 512)
        self.act5 = PerturbedReLU(epsilon=0)
        self.linear2 = nn.Linear(512, 5)
        self.flatten = nn.Flatten()
        self.softmax = nn.Softmax(dim=1)

    def forward(self, X):
        out = self.act1(self.conv1(X))
        out = self.act2(self.conv2(out))
        out = self.act3(self.conv3(out))
        out = self.act4(self.conv4(out))
        out = self.flatten(out)
        out = self.act5(self.linear1(out))
        out = self.softmax(self.linear2(out))
        return out

# %%
test_net_1 = TestNetwork1()
test_net_2 = TestNetwork2()
ctrl_net = ControlNetwork()
loss = nn.CrossEntropyLoss()
test_optimizer_1 = optim.Adam(test_net_1.parameters(), lr=1e-4)
test_optimizer_2 = optim.Adam(test_net_2.parameters(), lr=1e-4)
ctrl_optimizer = optim.Adam(ctrl_net.parameters(), lr=1e-4)

# %%
def get_accuracy(validloader, ctrl_net, test_net1, test_net2=None):
    ctrl_acc, test_acc1, test_acc2 = 0.0, 0.0, 0.0
    for X, y in validloader:
        with torch.no_grad():
            ctrl_out = ctrl_net(X)
            test_out1 = test_net1(X)
            if test_net2 is not None:
                test_out2 = test_net2(X)
        ctrl_acc += (ctrl_out.argmax(dim=1)==y).sum().item()
        test_acc1 += (test_out1.argmax(dim=1)==y).sum().item()
        if test_net2 is not None:
            test_acc2 += (test_out2.argmax(dim=1)==y).sum().item()
            return ctrl_acc/len(validloader), test_acc1/len(validloader), test_acc2/len(validloader)
        return ctrl_acc/len(validloader), test_acc1/len(validloader)

# %%
file_path = '/home/hari/Development/github/personal/ActivationFunctions/conventional_perturbed_constant_decaying.txt'
file = open(file_path, 'w')

# %%
num_epochs = 30
ctrl_losses, test_losses = [], []
line1 = f'{num_epochs} epochs\n'
line2 = 'Conventional ReLU vs Rerturbed ReLU with constant perturbation vs Perturbed ReLU with decaying perturbation on feature extraction\n'
file.write(line1)
file.write(line2)
for epoch in range(num_epochs):
    ctrl_running_loss, test_running_loss_1, test_running_loss_2 = 0.0, 0.0, 0.0
    for i, (X, y) in enumerate(dataloader):
        if i % 100 == 99:
            ctrl_acc, test_acc_1, test_acc_2 = get_accuracy(validloader, ctrl_net, test_net_1, test_net_2)
        ctrl_optimizer.zero_grad()
        test_optimizer_1.zero_grad()
        test_optimizer_2.zero_grad()
        ctrl_out = ctrl_net(X)
        test_out_1 = test_net_1(X)
        test_out_2 = test_net_2(X)
        ctrl_loss = loss(ctrl_out, y)
        ctrl_loss.backward()
        ctrl_optimizer.step()
        test_loss_1 = loss(test_out_1, y)
        test_loss_1.backward()
        test_optimizer_1.step()
        test_loss_2 = loss(test_out_2, y)
        test_loss_2.backward()
        test_optimizer_2.step()
        ctrl_running_loss += ctrl_loss.item()
        test_running_loss_1 += test_loss_1.item()
        test_running_loss_2 += test_loss_2.item()
        if i % 100 == 99:
            curr_ctrl_loss = ctrl_running_loss / 100
            ctrl_acc, test_acc_1, test_acc_2 = get_accuracy(validloader, ctrl_net, test_net_1, test_net_2)
            line = f'Epoch {epoch + 1} | Batch {i + 1}\nControl Accuracy: {ctrl_acc:.3f} | Test Constant Accuracy: {test_acc_1:.3f} | Test Decaying Accuracy: {test_acc_2:.3f}\nControl Loss: {ctrl_running_loss:.3f} | Test Constant Loss: {test_running_loss_1:.3f} | Test Decaying Loss: {test_running_loss_2:.3f}'
            with open(file_path, 'a') as file:
                file.write(line + '\n')
            ctrl_running_loss = 0.0
            test_running_loss_1 = 0.0
            test_running_loss_2 = 0.0
            print(line)
    print('----------------------------------------------------------------------------------')

# file.close()
# Out:
# Epoch 1, Batch 100, Control Accuracy: 0.256, Test Constant Accuracy: 0.274, Test Decaying Accuracy: 0.332, Control Loss: 160.429, Test Constant Loss: 160.898, Test Decaying Loss: 159.848
# Epoch 1, Batch 200, Control Accuracy: 0.288, Test Constant Accuracy: 0.274, Test Decaying Accuracy: 0.340, Control Loss: 158.071, Test Constant Loss: 159.564, Test Decaying Loss: 157.325
# Epoch 1, Batch 300, Control Accuracy: 0.239, Test Constant Accuracy: 0.274, Test Decaying Accuracy: 0.303, Control Loss: 158.940, Test Constant Loss: 161.284, Test Decaying Loss: 154.085
# Epoch 1, Batch 400, Control Accuracy: 0.303, Test Constant Accuracy: 0.274, Test Decaying Accuracy: 0.432, Control Loss: 155.291, Test Constant Loss: 160.151, Test Decaying Loss: 155.004
# Epoch 1, Batch 500, Control Accuracy: 0.323, Test Constant Accuracy: 0.266, Test Decaying Accuracy: 0.401, Control Loss: 153.224, Test Constant Loss: 158.999, Test Decaying Loss: 151.544
# Epoch 1, Batch 600, Control Accuracy: 0.266, Test Constant Accuracy: 0.386, Test Decaying Accuracy: 0.379, Control Loss: 154.935, Test Constant Loss: 155.615, Test Decaying Loss: 149.246
# Epoch 1, Batch 700, Control Accuracy: 0.333, Test Constant Accuracy: 0.417, Test Decaying Accuracy: 0.452, Control Loss: 156.981, Test Constant Loss: 154.094, Test Decaying Loss: 148.179
# ----------------------------------------------------------------------------------
# Epoch 2, Batch 100, Control Accuracy: 0.372, Test Constant Accuracy: 0.411, Test Decaying Accuracy: 0.434, Control Loss: 146.082, Test Constant Loss: 154.271, Test Decaying Loss: 145.922
# Epoch 2, Batch 200, Control Accuracy: 0.392, Test Constant Accuracy: 0.413, Test Decaying Accuracy: 0.432, Control Loss: 151.079, Test Constant Loss: 152.060, Test Decaying Loss: 147.284
# Epoch 2, Batch 300, Control Accuracy: 0.419, Test Constant Accuracy: 0.423, Test Decaying Accuracy: 0.445, Control Loss: 149.458, Test Constant Loss: 152.441, Test Decaying Loss: 150.013
# Epoch 2, Batch 400, Control Accuracy: 0.396, Test Constant Accuracy: 0.426, Test Decaying Accuracy: 0.385, Control Loss: 144.857, Test Constant Loss: 149.901, Test Decaying Loss: 147.156
# Epoch 2, Batch 500, Control Accuracy: 0.420, Test Constant Accuracy: 0.404, Test Decaying Accuracy: 0.422, Control Loss: 148.552, Test Constant Loss: 150.597, Test Decaying Loss: 149.943
# Epoch 2, Batch 600, Control Accuracy: 0.441, Test Constant Accuracy: 0.381, Test Decaying Accuracy: 0.442, Control Loss: 145.228, Test Constant Loss: 152.573, Test Decaying Loss: 144.796
# Epoch 2, Batch 700, Control Accuracy: 0.454, Test Constant Accuracy: 0.427, Test Decaying Accuracy: 0.465, Control Loss: 146.532, Test Constant Loss: 152.006, Test Decaying Loss: 147.017
# ----------------------------------------------------------------------------------
# Epoch 24, Batch 500, Control Accuracy: 0.604, Test Constant Accuracy: 0.645, Test Decaying Accuracy: 0.555, Control Loss: 131.206, Test Constant Loss: 130.107, Test Decaying Loss: 133.014
# Epoch 24, Batch 600, Control Accuracy: 0.415, Test Constant Accuracy: 0.648, Test Decaying Accuracy: 0.581, Control Loss: 131.678, Test Constant Loss: 124.918, Test Decaying Loss: 131.085
# Epoch 24, Batch 700, Control Accuracy: 0.490, Test Constant Accuracy: 0.600, Test Decaying Accuracy: 0.566, Control Loss: 145.241, Test Constant Loss: 125.766, Test Decaying Loss: 130.876
# ----------------------------------------------------------------------------------
# Epoch 25, Batch 100, Control Accuracy: 0.445, Test Constant Accuracy: 0.655, Test Decaying Accuracy: 0.572, Control Loss: 139.283, Test Constant Loss: 121.129, Test Decaying Loss: 132.507
# Epoch 25, Batch 200, Control Accuracy: 0.509, Test Constant Accuracy: 0.647, Test Decaying Accuracy: 0.544, Control Loss: 141.999, Test Constant Loss: 127.377, Test Decaying Loss: 131.405
# Epoch 25, Batch 300, Control Accuracy: 0.524, Test Constant Accuracy: 0.626, Test Decaying Accuracy: 0.584, Control Loss: 135.790, Test Constant Loss: 125.958, Test Decaying Loss: 131.177
# Epoch 25, Batch 400, Control Accuracy: 0.570, Test Constant Accuracy: 0.640, Test Decaying Accuracy: 0.533, Control Loss: 138.096, Test Constant Loss: 129.775, Test Decaying Loss: 134.254
# Epoch 25, Batch 500, Control Accuracy: 0.615, Test Constant Accuracy: 0.615, Test Decaying Accuracy: 0.505, Control Loss: 135.926, Test Constant Loss: 128.362, Test Decaying Loss: 137.760
# Epoch 25, Batch 600, Control Accuracy: 0.603, Test Constant Accuracy: 0.655, Test Decaying Accuracy: 0.569, Control Loss: 125.465, Test Constant Loss: 124.060, Test Decaying Loss: 127.557
# Epoch 25, Batch 700, Control Accuracy: 0.599, Test Constant Accuracy: 0.600, Test Decaying Accuracy: 0.559, Control Loss: 134.269, Test Constant Loss: 133.706, Test Decaying Loss: 133.479
# ----------------------------------------------------------------------------------
# Epoch 26, Batch 100, Control Accuracy: 0.573, Test Constant Accuracy: 0.628, Test Decaying Accuracy: 0.577, Control Loss: 129.894, Test Constant Loss: 127.882, Test Decaying Loss: 134.312
# Epoch 26, Batch 200, Control Accuracy: 0.543, Test Constant Accuracy: 0.633, Test Decaying Accuracy: 0.573, Control Loss: 135.026, Test Constant Loss: 121.058, Test Decaying Loss: 128.654
# Epoch 26, Batch 300, Control Accuracy: 0.577, Test Constant Accuracy: 0.513, Test Decaying Accuracy: 0.589, Control Loss: 133.645, Test Constant Loss: 127.257, Test Decaying Loss: 130.734
# Epoch 26, Batch 400, Control Accuracy: 0.566, Test Constant Accuracy: 0.619, Test Decaying Accuracy: 0.514, Control Loss: 135.076, Test Constant Loss: 130.839, Test Decaying Loss: 137.931
# Epoch 26, Batch 500, Control Accuracy: 0.607, Test Constant Accuracy: 0.529, Test Decaying Accuracy: 0.568, Control Loss: 132.958, Test Constant Loss: 127.036, Test Decaying Loss: 134.373
# Epoch 26, Batch 600, Control Accuracy: 0.602, Test Constant Accuracy: 0.634, Test Decaying Accuracy: 0.469, Control Loss: 132.716, Test Constant Loss: 128.416, Test Decaying Loss: 136.681
# Epoch 26, Batch 700, Control Accuracy: 0.587, Test Constant Accuracy: 0.634, Test Decaying Accuracy: 0.585, Control Loss: 129.441, Test Constant Loss: 126.821, Test Decaying Loss: 130.119
# ----------------------------------------------------------------------------------
# Epoch 27, Batch 100, Control Accuracy: 0.595, Test Constant Accuracy: 0.638, Test Decaying Accuracy: 0.576, Control Loss: 126.611, Test Constant Loss: 123.211, Test Decaying Loss: 141.891
# Epoch 27, Batch 200, Control Accuracy: 0.554, Test Constant Accuracy: 0.623, Test Decaying Accuracy: 0.554, Control Loss: 135.762, Test Constant Loss: 130.545, Test Decaying Loss: 134.888
# Epoch 27, Batch 300, Control Accuracy: 0.572, Test Constant Accuracy: 0.647, Test Decaying Accuracy: 0.585, Control Loss: 134.358, Test Constant Loss: 126.015, Test Decaying Loss: 133.148
# Epoch 27, Batch 400, Control Accuracy: 0.563, Test Constant Accuracy: 0.607, Test Decaying Accuracy: 0.550, Control Loss: 136.008, Test Constant Loss: 126.176, Test Decaying Loss: 133.113
# Epoch 27, Batch 500, Control Accuracy: 0.557, Test Constant Accuracy: 0.542, Test Decaying Accuracy: 0.544, Control Loss: 128.887, Test Constant Loss: 122.858, Test Decaying Loss: 131.740
# Epoch 27, Batch 600, Control Accuracy: 0.589, Test Constant Accuracy: 0.563, Test Decaying Accuracy: 0.492, Control Loss: 132.910, Test Constant Loss: 133.760, Test Decaying Loss: 133.785
# Epoch 27, Batch 700, Control Accuracy: 0.596, Test Constant Accuracy: 0.640, Test Decaying Accuracy: 0.479, Control Loss: 134.297, Test Constant Loss: 128.678, Test Decaying Loss: 141.487
# ----------------------------------------------------------------------------------
# Epoch 28, Batch 100, Control Accuracy: 0.606, Test Constant Accuracy: 0.604, Test Decaying Accuracy: 0.532, Control Loss: 129.996, Test Constant Loss: 125.366, Test Decaying Loss: 132.901
# Epoch 28, Batch 200, Control Accuracy: 0.589, Test Constant Accuracy: 0.610, Test Decaying Accuracy: 0.497, Control Loss: 133.298, Test Constant Loss: 132.485, Test Decaying Loss: 137.526
# Epoch 28, Batch 300, Control Accuracy: 0.510, Test Constant Accuracy: 0.638, Test Decaying Accuracy: 0.559, Control Loss: 139.067, Test Constant Loss: 129.034, Test Decaying Loss: 137.620
# Epoch 28, Batch 400, Control Accuracy: 0.512, Test Constant Accuracy: 0.648, Test Decaying Accuracy: 0.555, Control Loss: 148.712, Test Constant Loss: 125.422, Test Decaying Loss: 136.433
# Epoch 28, Batch 500, Control Accuracy: 0.563, Test Constant Accuracy: 0.630, Test Decaying Accuracy: 0.539, Control Loss: 133.980, Test Constant Loss: 120.929, Test Decaying Loss: 130.869
# Epoch 28, Batch 600, Control Accuracy: 0.532, Test Constant Accuracy: 0.653, Test Decaying Accuracy: 0.535, Control Loss: 134.394, Test Constant Loss: 126.739, Test Decaying Loss: 132.879
